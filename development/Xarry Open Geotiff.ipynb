# %% [markdown]
# # Opening a Geotiff with Xarray

# %% [markdown]
# ##Background
# It can be useful open other datasets into a notebook to conduct analysis on it or combine with data from DEA . In this example we will open a section of the NVIS major vegitation groups dataset published by DoEE avalible https://www.environment.gov.au/land/native-vegetation/national-vegetation-information-system

# %% [markdown]
# # #Load Packages

# %%
import xarray as xr
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Loading external data

# %% [markdown]
# Load in Geotiff

# %%
path_to_file = '/g/data1a/u46/users/ck9738/Datasets/NVIS_files/NVIS_major_veg_groups_ACT.tif'

# %%
data = xr.open_rasterio(path_to_file)
data
# Out:
# <xarray.DataArray (band: 1, y: 868, x: 616)>
# [534688 values with dtype=uint8]
# Coordinates:
#   * band     (band) int64 1
#   * y        (y) float64 -3.94e+06 -3.94e+06 -3.94e+06 ... -4.027e+06 -4.027e+06
#   * x        (x) float64 1.513e+06 1.513e+06 1.513e+06 ... 1.574e+06 1.574e+06
# Attributes:
#     transform:   (100.00288685064918, 0.0, 1512604.6716, 0.0, -99.95493894009...
#     crs:         +init=epsg:3577
#     res:         (100.00288685064918, 99.95493894009229)
#     is_tiled:    0
#     nodatavals:  (0.0,)
#     scales:      (1.0,)
#     offsets:     (0.0,)

# %%
data.plot(figsize =(13,15), cmap='gist_ncar_r', vmax=70)
