# %%
#Import Modules
import datacube
import datetime
import fiona
import geopandas as gpd
import numpy as np
import pandas as pd
import rasterio.mask
import rasterio.features
from shapely import geometry
import seaborn as sns
import sys
import xarray as xr

import matplotlib.dates as mdates
import matplotlib.gridspec as gridspec
import matplotlib.pyplot as plt

from datacube.storage import masking
from datacube.utils import geometry
from datacube.helpers import ga_pq_fuser, write_geotiff
from datacube.helpers import write_geotiff

sys.path.append('/g/data/u46/users/ck9738/10_Scripts')
import TasseledCapTools
#import DEADataHandling

dc = datacube.Datacube(app='tcw')

# %load_ext autoreload

# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
help(write_geotiff)
# Out:
# Help on function write_geotiff in module datacube.helpers:
#
# write_geotiff(filename, dataset, profile_override=None, time_index=None)
#     Write an ODC style xarray.Dataset to a GeoTIFF file.
#
#     :param filename: Output filename
#     :param dataset: xarray dataset containing one or more bands to write to a file.
#     :param profile_override: option dict, overrides rasterio file creation options.
#     :param time_index: DEPRECATED

# %%
#define area of interest
query = {
    
# #ever lasting swamp
# 'y': (-29.365, -29.489),
# 'x': (153.033, 153.200),
    
    
#lake Coleman
# 'y': (-38.103, -38.259),
# 'x': (147.098, 147.421),

         #Macquarie Marshes
# 'y': (-30.512, -30.977),
# 'x': (147.413, 147.809),
    
    #Daintree Rainforrest
'y': (-16.140, -16.209),
'x': (145.394, 145.460),    

    
    #Big Gunbower
# 'y': (-35.636, -35.905),
# 'x': (144.102, 144.387),
    
# jerrabombera wetland
#'y': (-35.288, -35.346),
#'x': (149.139, 149.191),

#ACT
# 'y': (-35.270, -35.336),
# 'x': (149.021, 149.194),    

    #lake george
# 'y': (-34.957, -35.221),
# 'x': (149.294, 149.519),   
    
#Kowen
# 'y': (-35.269, -35.354),
# 'x': (149.239, 149.396),   
    
#gunbower
# 'y': (-35.743, -35.909),
# 'x': (144.235, 144.387),
    
    
'time': ('2018-07-01', '2018-12-30'),
'crs': 'EPSG:4326',
'output_crs': 'EPSG: 3577',
'resolution': (-25, 25)
}

# %%
#load data
data_lst8 = dc.load(product='ls8_nbart_albers', group_by='solar_day', **query)
data_lst8
# Out:
# <xarray.Dataset>
# Dimensions:          (time: 11, x: 315, y: 333)
# Coordinates:
#   * time             (time) datetime64[ns] 2018-07-16T00:21:21.500000 ... 2018-12-23T00:22:04
#   * y                (y) float64 -1.792e+06 -1.792e+06 ... -1.801e+06 -1.801e+06
#   * x                (x) float64 1.437e+06 1.437e+06 ... 1.444e+06 1.444e+06
# Data variables:
#     coastal_aerosol  (time, y, x) int16 449 408 408 337 ... 4243 4319 4508 4522
#     blue             (time, y, x) int16 364 316 317 251 ... 4018 4104 4247 4264
#     green            (time, y, x) int16 456 432 432 359 ... 3829 3921 4058 4137
#     red              (time, y, x) int16 367 334 326 235 ... 3857 3937 4101 4176
#     nir              (time, y, x) int16 2519 2619 2782 2993 ... 4623 4795 4836
#     swir1            (time, y, x) int16 1035 1022 1029 969 ... 3735 3802 3858
#     swir2            (time, y, x) int16 607 564 519 409 ... 3487 3564 3643 3713
# Attributes:
#     crs:      EPSG: 3577

# %%
#define number of total observations

total_obs = int(len(data_lst8.time))
total_obs
# Out:
# 11

# %%
#load PG
sensor_pq = dc.load(product='ls8_pq_albers', fuse_func=ga_pq_fuser, group_by='solar_day', **query)
sensor_pq
# Out:
# <xarray.Dataset>
# Dimensions:       (time: 11, x: 315, y: 333)
# Coordinates:
#   * time          (time) datetime64[ns] 2018-07-16T00:21:21.500000 ... 2018-12-23T00:22:04
#   * y             (y) float64 -1.792e+06 -1.792e+06 ... -1.801e+06 -1.801e+06
#   * x             (x) float64 1.437e+06 1.437e+06 ... 1.444e+06 1.444e+06
# Data variables:
#     pixelquality  (time, y, x) int16 16383 16383 16383 ... 12799 12799 12799
# Attributes:
#     crs:      EPSG: 3577

# %%
#Mask Cloud

#make Mask
good_quality = masking.make_mask(sensor_pq.pixelquality,
                                 cloud_acca='no_cloud',
                                 cloud_fmask='no_cloud',
                                 cloud_shadow_acca='no_cloud_shadow',
                                 cloud_shadow_fmask='no_cloud_shadow',
                                 blue_saturated=False,
                                 green_saturated=False,
                                 red_saturated=False,
                                 nir_saturated=False,
                                 swir1_saturated=False,
                                 swir2_saturated=False,
                                 contiguous=True)
good_quality
# Out:
# <xarray.DataArray 'pixelquality' (time: 11, y: 333, x: 315)>
# array([[[ True,  True, ...,  True,  True],
#         [ True,  True, ...,  True,  True],
#         ...,
#         [ True,  True, ...,  True,  True],
#         [ True,  True, ...,  True,  True]],
#
#        [[ True,  True, ..., False, False],
#         [ True, False, ..., False, False],
#         ...,
#         [ True,  True, ...,  True,  True],
#         [ True,  True, ...,  True,  True]],
#
#        ...,
#
#        [[False, False, ..., False, False],
#         [False, False, ..., False, False],
#         ...,
#         [False, False, ..., False, False],
#         [False, False, ..., False, False]],
#
#        [[False, False, ..., False, False],
#         [False, False, ..., False, False],
#         ...,
#         [False, False, ..., False, False],
#         [False, False, ..., False, False]]])
# Coordinates:
#   * time     (time) datetime64[ns] 2018-07-16T00:21:21.500000 ... 2018-12-23T00:22:04
#   * y        (y) float64 -1.792e+06 -1.792e+06 ... -1.801e+06 -1.801e+06
#   * x        (x) float64 1.437e+06 1.437e+06 1.437e+06 ... 1.444e+06 1.444e+06

# %%
#apply Mask
Masked_lst8_data = data_lst8.where(good_quality)

# %%
data_lst8_once = Masked_lst8_data.isel(time=8
                                      )

#Prepare geomedian imagery for plotting

rgb = data_lst8_once.to_array(dim='color').sel(color=[
    'red','green', 'blue']).transpose('y', 'x', 'color')
fake_saturation = 2000.0  #you may need to adjust this to get a clear image. higher numbers will make it darker, 
                                                                            #lower will make it ligher
rgb = rgb.astype('double')
clipped_visible = rgb.where(rgb<fake_saturation).fillna(fake_saturation)
max_val = clipped_visible.max(['y', 'x'])
scaled = (clipped_visible / max_val)

fig = plt.figure(figsize =(15,15)) #edit size of plot 
plt.subplots_adjust(left=0.05, right=0.95, top=0.95, bottom=0.05) #set border dimensions
fig.patch.set_facecolor('white') #make border white 
fig.patch.set_alpha(0.99)#ensure border white
plt.axis('off')#remove axis 
plt.title('True Colour') #add title
plt.imshow(scaled, interpolation = 'nearest') #create image

# %%
#Do tassled Cap transformation
TCI = TasseledCapTools.thresholded_tasseled_cap(Masked_lst8_data,wetness_threshold=-1200, drop=True
                                                , drop_tc_bands=False)
tcw = TCI['wetness']
tcg = TCI['greenness']
tcb = TCI['brightness']

tcw.isel(time=8).plot()

# %%
#Apply wet classification over Data

wet_values = tcw.where(tcw<-350, 1) #first turn everything wet to 1
wet_values = wet_values.where(tcw>=-350,0) #then turn everything dry to 0

# %%
wet_values.isel(time=8).plot()

# %%
#Combine all date slices to gether to create a wetness frequency

wet_frequency = wet_values.sum(dim='time')
wet_frequency.plot(figsize =(15,15))

# %%
#Calulate what number of wetness observations is equal to X% of total observations

precent_threhold = total_obs*0.15
precent_threhold
# Out:
# 0.8999999999999999

# %%
#apply X% threshold to find area inundated for X amount of time

persistant_wet = wet_frequency.where(wet_frequency>precent_threhold)

persistant_wet.plot(figsize =(15,17))

# %%
#load wofs filtered summary
wofs_filtered_summary= dc.load(product = 'wofs_annual_summary',fuse_func='wofs_fuser', **query)
wofs_filtered_summary
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-41-d5ac9bbb680d> in <module>
#       1
#       2 #load wofs filtered summary
# ----> 3 wofs_filtered_summary= dc.load(product = 'wofs_annual_summary',fuse_func='wofs_fuser', **query)
#       4 wofs_filtered_summary
#
# /g/data/v10/public/modules/dea/20190329/lib/python3.6/site-packages/datacube/api/core.py in load(self, product, measurements, output_crs, resolution, resampling, skip_broken_datasets, dask_chunks, like, fuse_func, align, datasets, **query)
#     301                                 dask_chunks=dask_chunks,
#     302                                 skip_broken_datasets=skip_broken_datasets,
# --> 303                                 **legacy_args)
#     304
#     305         return apply_aliases(result, datacube_product, measurements)
#
# /g/data/v10/public/modules/dea/20190329/lib/python3.6/site-packages/datacube/api/core.py in load_data(sources, geobox, measurements, resampling, fuse_func, dask_chunks, skip_broken_datasets, **extra)
#     565         else:
#     566             return Datacube._xr_load(sources, geobox, measurements,
# --> 567                                      skip_broken_datasets=skip_broken_datasets)
#     568
#     569     @staticmethod
#
# /g/data/v10/public/modules/dea/20190329/lib/python3.6/site-packages/datacube/api/core.py in _xr_load(sources, geobox, measurements, skip_broken_datasets)
#     479
#     480                 _fuse_measurement(t_slice, datasets, geobox, m,
# --> 481                                   skip_broken_datasets=skip_broken_datasets)
#     482
#     483         return data
#
# /g/data/v10/public/modules/dea/20190329/lib/python3.6/site-packages/datacube/api/core.py in _fuse_measurement(dest, datasets, geobox, measurement, skip_broken_datasets)
#     685                        resampling=measurement.get('resampling_method', 'nearest'),
#     686                        fuse_func=measurement.get('fuser', None),
# --> 687                        skip_broken_datasets=skip_broken_datasets)
#     688
#     689
#
# /g/data/v10/public/modules/dea/20190329/lib/python3.6/site-packages/datacube/storage/_load.py in reproject_and_fuse(datasources, destination, dst_gbox, dst_nodata, resampling, fuse_func, skip_broken_datasets)
#      61
#      62                 if not roi_is_empty(roi):
# ---> 63                     fuse_func(destination[roi], buffer_[roi])
#      64                     buffer_[roi] = dst_nodata  # clean up for next read
#      65
#
# TypeError: 'str' object is not callable

# %%
wofs_water = wofs_filtered_summary['count_wet']
wofs_water

# %%
wofs_water.plot(figsize =(15,15))

# %%
Inundated_veg = persistant_wet.where(wofs_water<15)

# %%
Inundated_veg.plot(figsize =(15,15))

# %%
wofs_water['TCW']=Inundated_veg

# %%
wofs_water

# %%
#save some tassled cap to file
TCT_once = TCI.isel(time=8)
TCT_once
# Out:
# <xarray.Dataset>
# Dimensions:                 (x: 315, y: 333)
# Coordinates:
#     time                    datetime64[ns] 2018-11-21T00:22:07
#   * y                       (y) float64 -1.792e+06 -1.792e+06 ... -1.801e+06
#   * x                       (x) float64 1.437e+06 1.437e+06 ... 1.444e+06
# Data variables:
#     greenness               (y, x) float64 nan nan nan ... -107.8 -110.6 -111.1
#     greenness_thresholded   (y, x) float64 nan nan nan nan ... nan nan nan nan
#     brightness              (y, x) float64 nan nan nan nan ... 588.0 588.3 586.6
#     brightness_thresholded  (y, x) float64 nan nan nan nan ... nan nan nan nan
#     wetness                 (y, x) float64 nan nan nan nan ... 18.77 17.59 18.26
#     wetness_thresholded     (y, x) float64 nan nan nan nan ... 18.77 17.59 18.26
# Attributes:
#     crs:      EPSG: 3577

# %%
#write_geotiff(filename, dataset, profile_override=None, time_index=None)
write_geotiff('/g/data/u46/users/ck9738/Datasets/Tasselled_cap_tifs/Daintree_20181121.tif',TCT_once)
