# %%
import datacube
from datacube.storage import masking
from datacube import Datacube
from datetime import datetime
from skimage import exposure

#load requiered modules #load r 
import numpy as np
import rasterio
from rasterio import features
#from matplotlib import pyplot as plt #don't need unless want to plot
import xarray as xr
import pandas as pd
import geopandas as gpd
from geopandas import GeoSeries, GeoDataFrame

import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
#define nessisary gotiff handeling fuctions

import xarray, rasterio, numpy as np
def numpy_to_xarray(array, geobox, name=None):
    """Utility to convert ndarray to DataArray, using a datacube.model.GeoBox"""
    coords=[xarray.Coordinate(x, geobox.coords[x].values, attrs=dict(units=geobox.coords[x].units)) 
            for x in geobox.dims]
    return xarray.DataArray(array, coords=coords, attrs=dict(crs=geobox.crs), name=name)

def geopandas_to_xarray(table, geobox, name=None):
    """Rasterise (with reprojection)"""
    array = rasterio.features.rasterize(shapes=table.to_crs(geobox.crs._crs.ExportToProj4()).geometry,
                                        out_shape=(geobox.height, geobox.width),
                                        transform=geobox.affine)
    return numpy_to_xarray(array, geobox, name)

def rasterfile_to_xarray(file, geobox, name=None, nodata=True, num_bands=(1), X_band= 1):
    """Blit like
    """
    with rasterio.open(file) as src:

        #|assert src.indexes == num_bands # assume single band
        band = rasterio.band(src, X_band) # do not attempt to read entire extent into memory
        array = np.empty((geobox.height, geobox.width), dtype=band.dtype)
        rasterio.warp.reproject(source=band,
                                destination=array,
                                dst_crs=geobox.crs.crs_str,
                                dst_transform=geobox.affine,
                                dst_nodata=nodata)
    return numpy_to_xarray(array, geobox, name)


def load_gfif_full(file_name, x=1):


    dataset = rasterio.open(file_name) #open using Raterio
    {i: dtype for i, dtype in zip(dataset.indexes, dataset.dtypes)}
    data_array = dataset.read(x) #read selected band into np array
    data_xr = xr.DataArray(data_array) #turn into Xr array for fuctionality #Now don't need xr yet
    return(data_xr) #return np array into program 


def part_shp_file(geobox, file_path):
    #ucl_path = "/g/data/v10/wofs/ancillary/ucl/UCL_2011_AUST.shp"
    u = gpd.read_file(file_path) # load shapes table
    #u = u[u['SOS_NAME11']=='Major Urban'] # filter out <100k
    u = u.to_crs(geobox.crs._crs.ExportToProj4()) # reproject
    array = features.rasterize(shapes=zip(u.geometry, u.SecondaryA),
                                        out_shape=(geobox.height, geobox.width),
                                        transform=geobox.affine)
    return numpy_to_xarray(array, geobox, 'urban')

# %%
#Temporal range and sensors of interest are defined

#set the number of chunks to pass to dask 
#(bigger chunks will run the dc_load faster, but be careful of hitting memory limits)
ds_chunks = 20

#extents
# extent_long = (145.293, 145.553) reference area??
# extent_lat = (-30.665, -30.404)

extent_long = (148.122, 148.529)
extent_lat = (-32.567, -32.782)

#query is created
query = {}
query['x'] = extent_long
query['y'] = extent_lat
#query['crs'] = 'EPSG:3577'
#query['dask_chunks']= {'time' : ds_chunks} #divide query into chunks to save memory
    
print(query)
# Out:
# {'x': (148.122, 148.529), 'y': (-32.567, -32.782)}

# %%
#load area dem for geobox
#import datacube
dc = datacube.Datacube()

dsm = dc.load(product='dsm1sv10', **query)

# %%
#load mad_trees product

# %%
#load NSW landuse product
#file location

landuse_path = "/g/data/u46/users/ck9738/Datasets/Land_NSW_Landuse_2013/Data/Shapefile/NSW_Landuse_2013.shp"

landuse_data = part_shp_file(dsm.geobox, landuse_path)
# Out:
# I am densified (external_values, 1043185 elements)
# /g/data/v10/public/modules/dea-env/20180405/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: Coordinate has been deprecated. Use IndexVariable instead.
#   import sys

# %%
#load_majorVeggroups

veg_groups_path = '/g/data/u46/users/ck9738/Datasets/NVIS/major_veg_groups.tif'

veggroups_data = rasterfile_to_xarray(veg_groups_path, dsm.geobox, num_bands=(1), X_band=1)
# Out:
# /g/data/v10/public/modules/dea-env/20180405/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: Coordinate has been deprecated. Use IndexVariable instead.
#   import sys

# %%
! gdalinfo /g/data/u46/users/ck9738/Datasets/NVIS/major_veg_groups.tif
# Out:
# Driver: GTiff/GeoTIFF
# Files: /g/data/u46/users/ck9738/Datasets/NVIS/major_veg_groups.tif
#        /g/data/u46/users/ck9738/Datasets/NVIS/major_veg_groups.tif.ovr
#        /g/data/u46/users/ck9738/Datasets/NVIS/major_veg_groups.tif.aux.xml
# Size is 40100, 38370
# Coordinate System is:
# PROJCS["GDA_1994_Australia_Albers",
#     GEOGCS["GCS_GDA_1994",
#         DATUM["Geocentric_Datum_of_Australia_1994",
#             SPHEROID["GRS_1980",6378137,298.257222101,
#                 AUTHORITY["EPSG","7019"]],
#             AUTHORITY["EPSG","6283"]],
#         PRIMEM["Greenwich",0],
#         UNIT["degree",0.0174532925199433]],
#     PROJECTION["Albers_Conic_Equal_Area"],
#     PARAMETER["standard_parallel_1",-18],
#     PARAMETER["standard_parallel_2",-36],
#     PARAMETER["latitude_of_center",0],
#     PARAMETER["longitude_of_center",132],
#     PARAMETER["false_easting",0],
#     PARAMETER["false_northing",0],
#     UNIT["metre",1,
#         AUTHORITY["EPSG","9001"]]]
# Origin = (-1888000.000000000000000,-1004000.000000000000000)
# Pixel Size = (100.000000000000000,-100.000000000000000)
# Metadata:
#   AREA_OR_POINT=Area
# Image Structure Metadata:
#   INTERLEAVE=BAND
# Corner Coordinates:
# Upper Left  (-1888000.000,-1004000.000) (115d23'58.89"E,  8d26'28.63"S)
# Lower Left  (-1888000.000,-4841000.000) (109d30'15.68"E, 42d45'53.94"S)
# Upper Right ( 2122000.000,-1004000.000) (150d37'49.02"E,  8d 8'23.53"S)
# Lower Right ( 2122000.000,-4841000.000) (157d12'56.65"E, 42d21'44.58"S)
# Center      (  117000.000,-2922500.000) (133d11'34.54"E, 26d57'23.80"S)
# Band 1 Block=128x128 Type=Byte, ColorInterp=Palette
#   NoData Value=255
#   Overviews: 20050x19185, 10025x9593, 5013x4797, 2507x2399, 1254x1200, 627x600, 314x300, 157x150
#   Metadata:
#     RepresentationType=THEMATIC
#   Color Table (RGB with 256 entries)
#     0: 0,0,0,255
#     1: 255,0,0,255
#     2: 3,77,0,255
#     3: 0,130,0,255
#     4: 76,230,0,255
#     5: 193,214,200,255
#     6: 146,173,47,255
#     7: 144,186,141,255
#     8: 0,214,168,255
#     9: 178,235,178,255
#    10: 115,255,222,255
#    11: 224,255,235,255
#    12: 200,194,255,255
#    13: 240,228,141,255
#    14: 189,182,106,255
#    15: 138,114,19,255
#    16: 250,190,190,255
#    17: 138,114,101,255
#    18: 255,160,122,255
#    19: 184,171,141,255
#    20: 255,248,219,255
#    21: 252,228,167,255
#    22: 252,228,220,255
#    23: 21,163,171,255
#    24: 0,111,255,255
#    25: 255,255,255,255
#    26: 79,79,79,255
#    27: 204,204,204,255
#    28: 150,219,242,255
#    29: 156,156,156,255
#    30: 255,170,0,255
#    31: 214,157,188,255
#    32: 224,217,136,255
#    33: 0,0,0,255
#    34: 0,0,0,255
#    35: 0,0,0,255
#    36: 0,0,0,255
#    37: 0,0,0,255
#    38: 0,0,0,255
#    39: 0,0,0,255
#    40: 0,0,0,255
#    41: 0,0,0,255
#    42: 0,0,0,255
#    43: 0,0,0,255
#    44: 0,0,0,255
#    45: 0,0,0,255
#    46: 0,0,0,255
#    47: 0,0,0,255
#    48: 0,0,0,255
#    49: 0,0,0,255
#    50: 0,0,0,255
#    51: 0,0,0,255
#    52: 0,0,0,255
#    53: 0,0,0,255
#    54: 0,0,0,255
#    55: 0,0,0,255
#    56: 0,0,0,255
#    57: 0,0,0,255
#    58: 0,0,0,255
#    59: 0,0,0,255
#    60: 0,0,0,255
#    61: 0,0,0,255
#    62: 0,0,0,255
#    63: 0,0,0,255
#    64: 0,0,0,255
#    65: 0,0,0,255
#    66: 0,0,0,255
#    67: 0,0,0,255
#    68: 0,0,0,255
#    69: 0,0,0,255
#    70: 0,0,0,255
#    71: 0,0,0,255
#    72: 0,0,0,255
#    73: 0,0,0,255
#    74: 0,0,0,255
#    75: 0,0,0,255
#    76: 0,0,0,255
#    77: 0,0,0,255
#    78: 0,0,0,255
#    79: 0,0,0,255
#    80: 0,0,0,255
#    81: 0,0,0,255
#    82: 0,0,0,255
#    83: 0,0,0,255
#    84: 0,0,0,255
#    85: 0,0,0,255
#    86: 0,0,0,255
#    87: 0,0,0,255
#    88: 0,0,0,255
#    89: 0,0,0,255
#    90: 0,0,0,255
#    91: 0,0,0,255
#    92: 0,0,0,255
#    93: 0,0,0,255
#    94: 0,0,0,255
#    95: 0,0,0,255
#    96: 0,0,0,255
#    97: 0,0,0,255
#    98: 0,0,0,255
#    99: 235,235,235,255
#   100: 0,0,0,255
#   101: 0,0,0,255
#   102: 0,0,0,255
#   103: 0,0,0,255
#   104: 0,0,0,255
#   105: 0,0,0,255
#   106: 0,0,0,255
#   107: 0,0,0,255
#   108: 0,0,0,255
#   109: 0,0,0,255
#   110: 0,0,0,255
#   111: 0,0,0,255
#   112: 0,0,0,255
#   113: 0,0,0,255
#   114: 0,0,0,255
#   115: 0,0,0,255
#   116: 0,0,0,255
#   117: 0,0,0,255
#   118: 0,0,0,255
#   119: 0,0,0,255
#   120: 0,0,0,255
#   121: 0,0,0,255
#   122: 0,0,0,255
#   123: 0,0,0,255
#   124: 0,0,0,255
#   125: 0,0,0,255
#   126: 0,0,0,255
#   127: 0,0,0,255
#   128: 0,0,0,255
#   129: 0,0,0,255
#   130: 0,0,0,255
#   131: 0,0,0,255
#   132: 0,0,0,255
#   133: 0,0,0,255
#   134: 0,0,0,255
#   135: 0,0,0,255
#   136: 0,0,0,255
#   137: 0,0,0,255
#   138: 0,0,0,255
#   139: 0,0,0,255
#   140: 0,0,0,255
#   141: 0,0,0,255
#   142: 0,0,0,255
#   143: 0,0,0,255
#   144: 0,0,0,255
#   145: 0,0,0,255
#   146: 0,0,0,255
#   147: 0,0,0,255
#   148: 0,0,0,255
#   149: 0,0,0,255
#   150: 0,0,0,255
#   151: 0,0,0,255
#   152: 0,0,0,255
#   153: 0,0,0,255
#   154: 0,0,0,255
#   155: 0,0,0,255
#   156: 0,0,0,255
#   157: 0,0,0,255
#   158: 0,0,0,255
#   159: 0,0,0,255
#   160: 0,0,0,255
#   161: 0,0,0,255
#   162: 0,0,0,255
#   163: 0,0,0,255
#   164: 0,0,0,255
#   165: 0,0,0,255
#   166: 0,0,0,255
#   167: 0,0,0,255
#   168: 0,0,0,255
#   169: 0,0,0,255
#   170: 0,0,0,255
#   171: 0,0,0,255
#   172: 0,0,0,255
#   173: 0,0,0,255
#   174: 0,0,0,255
#   175: 0,0,0,255
#   176: 0,0,0,255
#   177: 0,0,0,255
#   178: 0,0,0,255
#   179: 0,0,0,255
#   180: 0,0,0,255
#   181: 0,0,0,255
#   182: 0,0,0,255
#   183: 0,0,0,255
#   184: 0,0,0,255
#   185: 0,0,0,255
#   186: 0,0,0,255
#   187: 0,0,0,255
#   188: 0,0,0,255
#   189: 0,0,0,255
#   190: 0,0,0,255
#   191: 0,0,0,255
#   192: 0,0,0,255
#   193: 0,0,0,255
#   194: 0,0,0,255
#   195: 0,0,0,255
#   196: 0,0,0,255
#   197: 0,0,0,255
#   198: 0,0,0,255
#   199: 0,0,0,255
#   200: 0,0,0,255
#   201: 0,0,0,255
#   202: 0,0,0,255
#   203: 0,0,0,255
#   204: 0,0,0,255
#   205: 0,0,0,255
#   206: 0,0,0,255
#   207: 0,0,0,255
#   208: 0,0,0,255
#   209: 0,0,0,255
#   210: 0,0,0,255
#   211: 0,0,0,255
#   212: 0,0,0,255
#   213: 0,0,0,255
#   214: 0,0,0,255
#   215: 0,0,0,255
#   216: 0,0,0,255
#   217: 0,0,0,255
#   218: 0,0,0,255
#   219: 0,0,0,255
#   220: 0,0,0,255
#   221: 0,0,0,255
#   222: 0,0,0,255
#   223: 0,0,0,255
#   224: 0,0,0,255
#   225: 0,0,0,255
#   226: 0,0,0,255
#   227: 0,0,0,255
#   228: 0,0,0,255
#   229: 0,0,0,255
#   230: 0,0,0,255
#   231: 0,0,0,255
#   232: 0,0,0,255
#   233: 0,0,0,255
#   234: 0,0,0,255
#   235: 0,0,0,255
#   236: 0,0,0,255
#   237: 0,0,0,255
#   238: 0,0,0,255
#   239: 0,0,0,255
#   240: 0,0,0,255
#   241: 0,0,0,255
#   242: 0,0,0,255
#   243: 0,0,0,255
#   244: 0,0,0,255
#   245: 0,0,0,255
#   246: 0,0,0,255
#   247: 0,0,0,255
#   248: 0,0,0,255
#   249: 0,0,0,255
#   250: 0,0,0,255
#   251: 0,0,0,255
#   252: 0,0,0,255
#   253: 0,0,0,255
#   254: 0,0,0,255
#   255: 0,0,0,0
# <GDALRasterAttributeTable>
#   <FieldDefn index="0">
#     <Name>OBJECTID</Name>
#     <Type>0</Type>
#     <Usage>0</Usage>
#   </FieldDefn>
#   <FieldDefn index="1">
#     <Name>VALUE</Name>
#     <Type>0</Type>
#     <Usage>0</Usage>
#   </FieldDefn>
#   <FieldDefn index="2">
#     <Name>COUNT</Name>
#     <Type>1</Type>
#     <Usage>0</Usage>
#   </FieldDefn>
#   <FieldDefn index="3">
#     <Name>MVG_NAME</Name>
#     <Type>2</Type>
#     <Usage>0</Usage>
#   </FieldDefn>
#   <FieldDefn index="4">
#     <Name>MVG_COMMON_DESC</Name>
#     <Type>2</Type>
#     <Usage>0</Usage>
#   </FieldDefn>
#   <FieldDefn index="5">
#     <Name>SORT_ORDER</Name>
#     <Type>0</Type>
#     <Usage>0</Usage>
#   </FieldDefn>
#   <Row index="0">
#     <F>1</F>
#     <F>1</F>
#     <F>3646905</F>
#     <F>Rainforests and Vine Thickets</F>
#     <F>rainforests</F>
#     <F>1</F>
#   </Row>
#   <Row index="1">
#     <F>2</F>
#     <F>2</F>
#     <F>3714845</F>
#     <F>Eucalypt Tall Open Forests</F>
#     <F>tall eucalypt forests (trees taller than 30 m)</F>
#     <F>2</F>
#   </Row>
#   <Row index="2">
#     <F>3</F>
#     <F>3</F>
#     <F>23425402</F>
#     <F>Eucalypt Open Forests</F>
#     <F>eucalypt forests (trees 10 to 30 m tall)</F>
#     <F>3</F>
#   </Row>
#   <Row index="3">
#     <F>4</F>
#     <F>4</F>
#     <F>1167389</F>
#     <F>Eucalypt Low Open Forests</F>
#     <F>low eucalypt forests (trees shorter than 10 m)</F>
#     <F>4</F>
#   </Row>
#   <Row index="4">
#     <F>5</F>
#     <F>5</F>
#     <F>84528297</F>
#     <F>Eucalypt Woodlands</F>
#     <F>eucalypt woodlands (tree crowns not touching)</F>
#     <F>5</F>
#   </Row>
#   <Row index="5">
#     <F>6</F>
#     <F>6</F>
#     <F>34156656</F>
#     <F>Acacia Forests and Woodlands</F>
#     <F>acacia forests and woodlands</F>
#     <F>6</F>
#   </Row>
#   <Row index="6">
#     <F>7</F>
#     <F>7</F>
#     <F>3415718</F>
#     <F>Callitris Forests and Woodlands </F>
#     <F>cypress pine forests and woodlands</F>
#     <F>7</F>
#   </Row>
#   <Row index="7">
#     <F>8</F>
#     <F>8</F>
#     <F>1657916</F>
#     <F>Casuarina Forests and Woodlands</F>
#     <F>she-oak forests and woodlands</F>
#     <F>8</F>
#   </Row>
#   <Row index="8">
#     <F>9</F>
#     <F>9</F>
#     <F>8142192</F>
#     <F>Melaleuca Forests and Woodlands </F>
#     <F>paperbark forests and woodlands</F>
#     <F>9</F>
#   </Row>
#   <Row index="9">
#     <F>10</F>
#     <F>10</F>
#     <F>4455005</F>
#     <F>Other Forests and Woodlands</F>
#     <F>other forests and woodlands</F>
#     <F>10</F>
#   </Row>
#   <Row index="10">
#     <F>11</F>
#     <F>11</F>
#     <F>46422956</F>
#     <F>Eucalypt Open Woodlands</F>
#     <F>sparse eucalypt woodlands</F>
#     <F>14</F>
#   </Row>
#   <Row index="11">
#     <F>12</F>
#     <F>12</F>
#     <F>13572816</F>
#     <F>Tropical Eucalypt Woodlands/Grasslands</F>
#     <F>tropical eucalypt woodlands with annual tussock grasses taller than 2 m</F>
#     <F>11</F>
#   </Row>
#   <Row index="12">
#     <F>13</F>
#     <F>13</F>
#     <F>38272902</F>
#     <F>Acacia Open Woodlands</F>
#     <F>sparse acacia woodlands</F>
#     <F>15</F>
#   </Row>
#   <Row index="13">
#     <F>14</F>
#     <F>14</F>
#     <F>21376333</F>
#     <F>Mallee Woodlands and Shrublands</F>
#     <F>mallee eucalypt woodlands and shrublands</F>
#     <F>12</F>
#   </Row>
#   <Row index="14">
#     <F>15</F>
#     <F>15</F>
#     <F>1758042</F>
#     <F>Low Closed Forests and Tall Closed Shrublands</F>
#     <F>tall dense thickets</F>
#     <F>18</F>
#   </Row>
#   <Row index="15">
#     <F>16</F>
#     <F>16</F>
#     <F>85536647</F>
#     <F>Acacia Shrublands</F>
#     <F>acacia shrublands</F>
#     <F>19</F>
#   </Row>
#   <Row index="16">
#     <F>17</F>
#     <F>17</F>
#     <F>12268546</F>
#     <F>Other Shrublands</F>
#     <F>other shrublands</F>
#     <F>20</F>
#   </Row>
#   <Row index="17">
#     <F>18</F>
#     <F>18</F>
#     <F>1442923</F>
#     <F>Heathlands</F>
#     <F>heathlands (low, dense, fine-leaved shrublands)</F>
#     <F>21</F>
#   </Row>
#   <Row index="18">
#     <F>19</F>
#     <F>19</F>
#     <F>52714741</F>
#     <F>Tussock Grasslands</F>
#     <F>grasslands</F>
#     <F>22</F>
#   </Row>
#   <Row index="19">
#     <F>20</F>
#     <F>20</F>
#     <F>137284140</F>
#     <F>Hummock Grasslands</F>
#     <F>arid spinifex grasslands</F>
#     <F>23</F>
#   </Row>
#   <Row index="20">
#     <F>21</F>
#     <F>21</F>
#     <F>4962995</F>
#     <F>Other Grasslands, Herblands, Sedgelands and Rushlands</F>
#     <F>swampy grasses, sedges, etc.</F>
#     <F>24</F>
#   </Row>
#   <Row index="21">
#     <F>22</F>
#     <F>22</F>
#     <F>48917553</F>
#     <F>Chenopod Shrublands, Samphire Shrublands and Forblands</F>
#     <F>saltbushes and salt marshes</F>
#     <F>25</F>
#   </Row>
#   <Row index="22">
#     <F>23</F>
#     <F>23</F>
#     <F>1049111</F>
#     <F>Mangroves</F>
#     <F>mangroves</F>
#     <F>26</F>
#   </Row>
#   <Row index="23">
#     <F>24</F>
#     <F>24</F>
#     <F>8342951</F>
#     <F>Inland aquatic - freshwater, salt lakes, lagoons</F>
#     <F>water</F>
#     <F>27</F>
#   </Row>
#   <Row index="24">
#     <F>25</F>
#     <F>25</F>
#     <F>103263048</F>
#     <F>Cleared, non-native vegetation, buildings</F>
#     <F>cleared vegetation</F>
#     <F>28</F>
#   </Row>
#   <Row index="25">
#     <F>26</F>
#     <F>26</F>
#     <F>179277</F>
#     <F>Unclassified native vegetation</F>
#     <F>unclassified native vegetation</F>
#     <F>29</F>
#   </Row>
#   <Row index="26">
#     <F>27</F>
#     <F>27</F>
#     <F>1595721</F>
#     <F>Naturally bare - sand, rock, claypan, mudflat</F>
#     <F>naturally bare</F>
#     <F>30</F>
#   </Row>
#   <Row index="27">
#     <F>28</F>
#     <F>28</F>
#     <F>89509</F>
#     <F>Sea and estuaries</F>
#     <F>sea</F>
#     <F>31</F>
#   </Row>
#   <Row index="28">
#     <F>29</F>
#     <F>29</F>
#     <F>1236766</F>
#     <F>Regrowth, modified native vegetation</F>
#     <F>regrowth</F>
#     <F>32</F>
#   </Row>
#   <Row index="29">
#     <F>30</F>
#     <F>30</F>
#     <F>99125</F>
#     <F>Unclassified Forest</F>
#     <F>forest</F>
#     <F>13</F>
#   </Row>
#   <Row index="30">
#     <F>31</F>
#     <F>31</F>
#     <F>16960581</F>
#     <F>Other Open Woodlands</F>
#     <F>other sparse woodlands</F>
#     <F>17</F>
#   </Row>
#   <Row index="31">
#     <F>32</F>
#     <F>32</F>
#     <F>2077874</F>
#     <F>Mallee Open Woodlands and Sparse Mallee Shrublands</F>
#     <F>sparse mallee eucalypt woodlands and shrublands</F>
#     <F>16</F>
#   </Row>
#   <Row index="32">
#     <F>33</F>
#     <F>99</F>
#     <F>1350186</F>
#     <F>Unknown/no data</F>
#     <F>unknown</F>
#     <F>33</F>
#   </Row>
# </GDALRasterAttributeTable>

# %%
veggroups_data
# Out:
# <xarray.DataArray (latitude: 775, longitude: 1466)>
# array([[25, 25, 25, ..., 25, 25, 25],
#        [25, 25, 25, ..., 25, 25, 25],
#        [25, 25, 25, ..., 25, 25, 25],
#        ...,
#        [25, 25, 25, ..., 19, 19, 19],
#        [25, 25, 25, ..., 19, 19, 19],
#        [25, 25, 25, ..., 19, 19, 19]], dtype=uint8)
# Coordinates:
#   * latitude   (latitude) float64 -32.57 -32.57 -32.57 -32.57 -32.57 -32.57 ...
#   * longitude  (longitude) float64 148.1 148.1 148.1 148.1 148.1 148.1 148.1 ...
# Attributes:
#     crs:      EPSG:4326

# %%
landuse_data.plot();

# %%
#generate list of random points for 
import random
random.seed()
randlist = [ ( random.randint(1, 1465), random.randint(1, 774) ) for k in range(1500) ]
#print(randlist)

# %%
fig, ax = plt.subplots(figsize = (15,15))
cax = ax.imshow(veggroups_data)
plt.title('pixle drill points')
plt.scatter(*zip(*randlist),c='r', s=60)
#cax.set_clim(0, 35)
plt.show()

# %%
mad_data = {}

# %%
#begin pixle drill

#define bands to loop through in mad dataset
bands = [1,2,3]

#create dicts to store data

result_dit = dict()

#define count 
count = 0
#begin loop. 
for x,y in randlist:
    mini_dit = dict()#smaller dict to nest in bigger one, this becomes a row in the table

    tup_x = int(x)
    tup_y = int(y)
    count = count+1
    #mini_dit['point']=count
    classifcation = landuse_data.isel(latitude=tup_y,longitude=tup_x)
    lat=(str(classifcation.latitude))
    lon=(str(classifcation.longitude))
    lat_short = lat[39:49]
    lon_short = lon[40:50]
    #print(lat)
    #print(lat_short, lon_short)
    mini_dit['class']=str(classifcation.values)
    mini_dit['latitude']=str(lat_short)
    mini_dit['longitude']=str(lon_short)
    #do Pixle drill for major veggie groups 
    veggi_group = veggroups_data.isel(latitude=tup_y,longitude=tup_x)
    mini_dit['Veg_group']=str(veggi_group.values)
    
    
    #loop through all three bands of mad trees

    for band in bands:

        name = 'band '+str(band)
        data = rasterfile_to_xarray("/g/data/u46/users/dxr251/small/woody.tif", dsm.geobox,
                                        num_bands=(1, 2, 3), X_band=band)#load band
        value = data.isel(latitude=tup_y,longitude=tup_x)#pixle drill. 
        mini_dit[name]=str(value.values)
    result_dit[count]=mini_dit
    #end loop
#result_dit
# Out:
# /g/data/v10/public/modules/dea-env/20180405/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: Coordinate has been deprecated. Use IndexVariable instead.
#   import sys

# %%
new_DLCD_panda = pd.DataFrame(result_dit)

# %%
new_DLCD_panda
# Out:
#                   1             2            3             4             5     \
# Veg_group           25             5           25            25            25
# band 1     0.013569473  0.0025545552  0.030022385  0.0028597373  0.0028581042
# band 2      0.42944208    0.57265246   0.57682467    0.32241482    0.30985948
# band 3      0.40395296    0.55476177    0.5312416    0.32944274    0.31474915
# class              330           130          330           320           210
# latitude    -32.672361    -32.592917   -32.715139    -32.756528    -32.56875)
# longitude   148.206806    148.525139   148.432917    148.279028    148.12375)
#
#                  6             7            8            9            10    \
# Veg_group          25            29            7            5           25
# band 1     0.00477166  0.0025885713  0.002704773  0.004520297  0.006874921
# band 2      0.5032994     0.5040003   0.44635567    0.6224824   0.39838043
# band 3       0.493191     0.4939916   0.44148126    0.6016323   0.38172123
# class             130           210          210          110          320
# latitude   -32.584583    -32.615694   -32.655972   -32.685972   -32.643472
# longitude  148.329306    148.517083   148.28625)   148.384028   148.27125)
#
#               ...             1491         1492         1493          1494  \
# Veg_group     ...                7           26           25             5
# band 1        ...        0.0048507  0.004581323  0.008339983  0.0036630312
# band 2        ...        0.5627909   0.33443776   0.36623588    0.59773517
# band 3        ...        0.5339695   0.33892336   0.36092103     0.5672732
# class         ...              110          330          330           130
# latitude      ...       -32.632917   -32.671528   -32.680139    -32.598194
# longitude     ...       148.321528   148.15625)   148.163194    148.395694
#
#                    1495         1496         1497        1498         1499  \
# Veg_group             5           25            7          25           29
# band 1     0.0030576256  0.007876128  0.004937381  0.01884976  0.004610315
# band 2        0.6010306   0.38682678    0.6091092  0.42036286   0.53231776
# band 3        0.5801827   0.38173512   0.58275807   0.3212468     0.517037
# class               130          320          110         330          210
# latitude     -32.607917   -32.642639   -32.711528  -32.703472   -32.655694
# longitude    148.382639   148.267639   148.35125)  148.180417   148.495694
#
#                   1500
# Veg_group           25
# band 1     0.015498268
# band 2      0.48685858
# band 3       0.4616384
# class              330
# latitude    -32.72375)
# longitude   148.402083
#
# [7 rows x 1500 columns]

# %%
new_DLCD_panda.to_csv('/g/data/u46/users/ck9738/Datasets/pixle_drill_data_huge.csv')

# %%
x_data = np.random.randint(0,1000,size=(2,10))
x_data
